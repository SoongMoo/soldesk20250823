# %%
# !pip install pandas
# Out:
# Requirement already satisfied: pandas in /usr/local/lib/python3.12/dist-packages (2.2.2)
# Requirement already satisfied: numpy>=1.26.0 in /usr/local/lib/python3.12/dist-packages (from pandas) (2.0.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas) (2025.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)

# %%
# 판다 시작하기
# 리터널 : 정수 , 실수 , 문자열
# 부울
# 파이썬 : 리스트 , 튜플, 딕셔너리, 집합
# numpy : 숫자 배열 : 리스트
# pandas : 시리즈 : 1차원배열 : 벡터 : 리스트 : 값이 1개인 딕셔너리
#          DataFrame : 2차원배원 : 값이 2개이상인 딕셔너리

# %%
import pandas as pd
# 시리즈
obj = pd.Series([4, 7, -5, 3])
print(obj)
print(obj[0])
print(obj.index)
# Out:
# 0    4
# 1    7
# 2   -5
# 3    3
# dtype: int64
# 4
# RangeIndex(start=0, stop=4, step=1)

# %%
import numpy as np
arr = obj.to_numpy() # 1차원 배열
print(arr)
print(obj)
print(np.sum(obj))
print(np.sum(arr))
# Out:
# [ 4  7 -5  3]
# 0    4
# 1    7
# 2   -5
# 3    3
# dtype: int64
# RangeIndex(start=0, stop=4, step=1)
# 9
# 9

# %%
obj = pd.Series([4, 7, -5, 3])
print(obj)
print(obj[0])
# Out:
# 0    4
# 1    7
# 2   -5
# 3    3
# dtype: int64
# 4

# %%
obj = pd.Series([4, 7, -5, 3], index = ['a','b','c','d'])
print(obj)
print(obj['a']) # 명시적 index
# print(obj[0]) # 암시적 index
l = [1,2,3,4]
print(l[0])
#print(l[0,1,2])
arr =  np.array([1,2,3,4])
print(arr[0])
print(arr[[0,1,2]])
print(obj[['a','b','c']])
# Out:
# a    4
# b    7
# c   -5
# d    3
# dtype: int64
# 4
# 1
# 1
# [1 2 3]
# a    4
# b    7
# c   -5
# dtype: int64

# %%
print(arr)
print(arr[arr > 2]) # 부울 index
print(obj[obj > 2])
# Out:
# [1 2 3 4]
# [3 4]
# a    4
# b    7
# d    3
# dtype: int64

# %%
# in 연산자
print( 'a' in obj) # obj에 index가 있는지 확인
print( 0 in obj)
print('e' in obj)
# Out:
# True
# False
# False

# %%
# 딕셔너리를 이용한 시리즈
dic = obj.to_dict()
print(dic)
sdata = pd.Series({"Ohio": 35000, "Texas": 71000, "Oregon": 16000, "Utah": 5000})
print(sdata) # 딕셔너리의 키는 시리즈의 index가 됨
dic1 = {"Ohio": 35000, "Texas": 71000, "Oregon": 16000, "Utah": 5000}
sdata1 = pd.Series(dic1)
print(sdata)
# Out:
# {'a': 4, 'b': 7, 'c': -5, 'd': 3}
# Ohio      35000
# Texas     71000
# Oregon    16000
# Utah       5000
# dtype: int64
# Ohio      35000
# Texas     71000
# Oregon    16000
# Utah       5000
# dtype: int64

# %%
dic1 = {"Ohio": 35000, "Texas": 71000, "Oregon": 16000, "Utah": 5000}
sdata1 = pd.Series(dic1, index=["California", "Ohio", "Oregon", "Texas"])
print(sdata1)
# NaN : 누락값
print(pd.isna(sdata1))
print(pd.notna(sdata1))
print(sdata1.isna())
# Out:
# California        NaN
# Ohio          35000.0
# Oregon        16000.0
# Texas         71000.0
# dtype: float64
# California     True
# Ohio          False
# Oregon        False
# Texas         False
# dtype: bool
# California    False
# Ohio           True
# Oregon         True
# Texas          True
# dtype: bool
# California     True
# Ohio          False
# Oregon        False
# Texas         False
# dtype: bool

# %%
#  연산
print(sdata)
print(sdata1)
print(sdata + sdata1) # index끼리의 연산이 된다.
sdata.name="이숭무" # 시이즈에 이름 주기
sdata.index.name='state' # index에 이름 주기
print(sdata)
# Out:
# Ohio      35000
# Texas     71000
# Oregon    16000
# Utah       5000
# dtype: int64
# California        NaN
# Ohio          35000.0
# Oregon        16000.0
# Texas         71000.0
# dtype: float64
# California         NaN
# Ohio           70000.0
# Oregon         32000.0
# Texas         142000.0
# Utah               NaN
# dtype: float64
# state
# Ohio      35000
# Texas     71000
# Oregon    16000
# Utah       5000
# Name: 이숭무, dtype: int64

# %%
# index 순서 바꾸기
sdata.index=['Oregon','Utah','Ohio','Texas']
print(sdata)
# Out:
# Oregon    35000
# Utah      71000
# Ohio      16000
# Texas      5000
# Name: 이숭무, dtype: int64

# %%
# 데이터 프레임
data = {"state": ["Ohio", "Ohio", "Ohio", "Nevada", "Nevada", "Nevada"],
        "year": [2000, 2001, 2002, 2001, 2002, 2003],
        "pop": [1.5, 1.7, 3.6, 2.4, 2.9, 3.2]}
df = pd.DataFrame(data)
df
df.head() # 5개 행   n=5
df.head(n=3)
df.head(n=7)
df.tail()
df.tail(n= 3)
# Out:
#     state  year  pop
# 3  Nevada  2001  2.4
# 4  Nevada  2002  2.9
# 5  Nevada  2003  3.2

# %%
# 열의 순서를 변경하면서 dataframe 만들기
df1 = pd.DataFrame(data, columns=['year','pop','state'])
df1
# Out:
#    year  pop   state
# 0  2000  1.5    Ohio
# 1  2001  1.7    Ohio
# 2  2002  3.6    Ohio
# 3  2001  2.4  Nevada
# 4  2002  2.9  Nevada
# 5  2003  3.2  Nevada

# %%
# 열을 출력
df2 = pd.DataFrame(data, columns=['year','pop','state','debt'])
print(df2)
print(df2['state'])
print(type(df2['state']))
print(df2.state)
print(df2['state'][0])
# Out:
#    year  pop   state debt
# 0  2000  1.5    Ohio  NaN
# 1  2001  1.7    Ohio  NaN
# 2  2002  3.6    Ohio  NaN
# 3  2001  2.4  Nevada  NaN
# 4  2002  2.9  Nevada  NaN
# 5  2003  3.2  Nevada  NaN
# 0      Ohio
# 1      Ohio
# 2      Ohio
# 3    Nevada
# 4    Nevada
# 5    Nevada
# Name: state, dtype: object
# <class 'pandas.core.series.Series'>
# 0      Ohio
# 1      Ohio
# 2      Ohio
# 3    Nevada
# 4    Nevada
# 5    Nevada
# Name: state, dtype: object
# Ohio

# %%
# 행출력
print(df2)
print(df2['year'])
#print(df2[0])
print(df2.loc[0])
l = [1,2,3,4]
print(l)
print(l[0]) # 암시적 index
print(df2.loc[2]) # 명시적 index
print(df2.iloc[2]) # 암시적 index
print(df2.iloc[-4])  # 암시적 index
# print(df2.loc[-4])
# Out:
#    year  pop   state debt
# 0  2000  1.5    Ohio  NaN
# 1  2001  1.7    Ohio  NaN
# 2  2002  3.6    Ohio  NaN
# 3  2001  2.4  Nevada  NaN
# 4  2002  2.9  Nevada  NaN
# 5  2003  3.2  Nevada  NaN
# 0    2000
# 1    2001
# 2    2002
# 3    2001
# 4    2002
# 5    2003
# Name: year, dtype: int64
# year     2000
# pop       1.5
# state    Ohio
# debt      NaN
# Name: 0, dtype: object
# [1, 2, 3, 4]
# 1
# year     2002
# pop       3.6
# state    Ohio
# debt      NaN
# Name: 2, dtype: object
# year     2002
# pop       3.6
# state    Ohio
# debt      NaN
# Name: 2, dtype: object
# year     2002
# pop       3.6
# state    Ohio
# debt      NaN
# Name: 2, dtype: object

# %%
print(df2)
df2['debt'] = 16.5
print(df2)
# Out:
#    year  pop   state debt
# 0  2000  1.5    Ohio  NaN
# 1  2001  1.7    Ohio  NaN
# 2  2002  3.6    Ohio  NaN
# 3  2001  2.4  Nevada  NaN
# 4  2002  2.9  Nevada  NaN
# 5  2003  3.2  Nevada  NaN
#    year  pop   state  debt
# 0  2000  1.5    Ohio  16.5
# 1  2001  1.7    Ohio  16.5
# 2  2002  3.6    Ohio  16.5
# 3  2001  2.4  Nevada  16.5
# 4  2002  2.9  Nevada  16.5
# 5  2003  3.2  Nevada  16.5

# %%
df2['debt'] = np.arange(6,) #  0   5의 값으로 순차적으로 채움
print(df2)
# Out:
#    year  pop   state  debt
# 0  2000  1.5    Ohio     0
# 1  2001  1.7    Ohio     1
# 2  2002  3.6    Ohio     2
# 3  2001  2.4  Nevada     3
# 4  2002  2.9  Nevada     4
# 5  2003  3.2  Nevada     5

# %%
val = pd.Series([-1.2, -1.5, -1.7], index=[2, 4, 5])
print(val)
df2['debt'] = val # dataFrame의 열 index와 Series의 index가 같은 index만 값이 채워짐
df2
# Out:
# 2   -1.2
# 4   -1.5
# 5   -1.7
# dtype: float64
#    year  pop   state  debt
# 0  2000  1.5    Ohio   NaN
# 1  2001  1.7    Ohio   NaN
# 2  2002  3.6    Ohio  -1.2
# 3  2001  2.4  Nevada   NaN
# 4  2002  2.9  Nevada  -1.5
# 5  2003  3.2  Nevada  -1.7

# %%
# 부울 index
print(df2["state"] == "Ohio")
df2["eastern"] = df2["state"] == "Ohio"
df2
# 딕셔너리와 동일하게 열(키)이 있는 수정 열이 없으면 추가
# Out:
# 0     True
# 1     True
# 2     True
# 3    False
# 4    False
# 5    False
# Name: state, dtype: bool
#    year  pop   state  debt  eastern
# 0  2000  1.5    Ohio   NaN     True
# 1  2001  1.7    Ohio   NaN     True
# 2  2002  3.6    Ohio  -1.2     True
# 3  2001  2.4  Nevada   NaN    False
# 4  2002  2.9  Nevada  -1.5    False
# 5  2003  3.2  Nevada  -1.7    False

# %%
print(df2)
print(df2['eastern'])
del df2['eastern']
df
# Out:
#    year  pop   state  debt  eastern
# 0  2000  1.5    Ohio   NaN     True
# 1  2001  1.7    Ohio   NaN     True
# 2  2002  3.6    Ohio  -1.2     True
# 3  2001  2.4  Nevada   NaN    False
# 4  2002  2.9  Nevada  -1.5    False
# 5  2003  3.2  Nevada  -1.7    False
# 0     True
# 1     True
# 2     True
# 3    False
# 4    False
# 5    False
# Name: eastern, dtype: bool
#     state  year  pop
# 0    Ohio  2000  1.5
# 1    Ohio  2001  1.7
# 2    Ohio  2002  3.6
# 3  Nevada  2001  2.4
# 4  Nevada  2002  2.9
# 5  Nevada  2003  3.2

# %%
print(df2.columns) # 컬럼명을 출력
# Out:
# Index(['year', 'pop', 'state', 'debt'], dtype='object')

# %%
populations = {"Ohio": {2000: 1.5, 2001: 1.7, 2002: 3.6}, # index
               "Nevada": {2001: 2.4, 2002: 2.9}}
df3 = pd.DataFrame(populations)
print(df3)
print(df3.T)
df4 = pd.DataFrame(populations , index=[2001,2002,2003])
print(df4)
# Out:
#       Ohio  Nevada
# 2000   1.5     NaN
# 2001   1.7     2.4
# 2002   3.6     2.9
#         2000  2001  2002
# Ohio     1.5   1.7   3.6
# Nevada   NaN   2.4   2.9
#       Ohio  Nevada
# 2001   1.7     2.4
# 2002   3.6     2.9
# 2003   NaN     NaN

# %%
# Series에 대한 indexing과 Slicing
print(df3)
print(df3['Ohio'])
print(df3['Ohio'][2001])
print(df3['Ohio'][:])
print(df3['Ohio'][:-1]) # 2002 전까지 # 암시적 index
print(df3['Ohio'][:2])
# Out:
#       Ohio  Nevada
# 2000   1.5     NaN
# 2001   1.7     2.4
# 2002   3.6     2.9
# 2000    1.5
# 2001    1.7
# 2002    3.6
# Name: Ohio, dtype: float64
# 1.7
# 2000    1.5
# 2001    1.7
# 2002    3.6
# Name: Ohio, dtype: float64
# 2000    1.5
# 2001    1.7
# Name: Ohio, dtype: float64
# 2000    1.5
# 2001    1.7
# Name: Ohio, dtype: float64

# %%
print(df3)
pdata = {"Ohio" : df3['Ohio'][:-1],
         "Nevada" : df3['Nevada'][:2]}
print(pdata)
pd.DataFrame(pdata)
# Out:
#       Ohio  Nevada
# 2000   1.5     NaN
# 2001   1.7     2.4
# 2002   3.6     2.9
# {'Ohio': 2000    1.5
# 2001    1.7
# Name: Ohio, dtype: float64, 'Nevada': 2000    NaN
# 2001    2.4
# Name: Nevada, dtype: float64}
#       Ohio  Nevada
# 2000   1.5     NaN
# 2001   1.7     2.4

# %%
df3.name = '이수무'
df3.columns.name = '이장범'
df3.index.name='이상범'
df3
# Out:
# 이장범   Ohio  Nevada
# 이상범
# 2000   1.5     NaN
# 2001   1.7     2.4
# 2002   3.6     2.9

# %%
df3.to_numpy()
# Out:
# array([[1.5, nan],
#        [1.7, 2.4],
#        [3.6, 2.9]])

# %%
# column이 있는지
print("Ohio" in df3.columns)
# index가 있는지
print(2002 in df3.index)
print(df3.columns)
# Out:
# True
# True
# Index(['Ohio', 'Nevada'], dtype='object', name='이장범')

# %%
# Reindexing
obj = pd.Series([4.5, 7.2, -5.3, 3.6], index=["d", "b", "a", "c"])
obj
# Out:
# d    4.5
# b    7.2
# a   -5.3
# c    3.6
# dtype: float64

# %%
print(obj)
obj2 = obj.reindex(["a", "b", "c", "d", "e"]) # index의 순서 변경
print(obj2)
# Out:
# d    4.5
# b    7.2
# a   -5.3
# c    3.6
# dtype: float64
# a   -5.3
# b    7.2
# c    3.6
# d    4.5
# e    NaN
# dtype: float64

# %%
obj3 = pd.Series(["blue", "purple", "yellow"], index=[0, 2, 4])
print(obj3)
reindexed = obj3.reindex(np.arange(6), method='ffill')
print(reindexed)
reindexed = obj3.reindex(np.arange(6), method='bfill')
print(reindexed)
# Out:
# 0      blue
# 2    purple
# 4    yellow
# dtype: object
# 0      blue
# 1      blue
# 2    purple
# 3    purple
# 4    yellow
# 5    yellow
# dtype: object
# 0      blue
# 1    purple
# 2    purple
# 3    yellow
# 4    yellow
# 5       NaN
# dtype: object

# %%
frame = pd.DataFrame(np.arange(9).reshape((3, 3)),
                     index=["a", "c", "d"],
                     columns=["Ohio", "Texas", "California"])
print(frame)
frame2 = frame.reindex(index=["a", "b", "c", "d"]) # index를 재정의 할 경우 없던 index에는 값이 NaN이 된다.
print(frame2)
# Out:
#    Ohio  Texas  California
# a     0      1           2
# c     3      4           5
# d     6      7           8
#    Ohio  Texas  California
# a   0.0    1.0         2.0
# b   NaN    NaN         NaN
# c   3.0    4.0         5.0
# d   6.0    7.0         8.0

# %%
print(frame)
print(frame['Ohio'])
print(type(frame['Ohio']))
print(frame.loc['a'])
print(type(frame.loc['a']))
print(frame.loc['a']['Ohio'])
print(frame.loc[['a','c','d']])
print(type(frame.loc[['a','c','d']]))
print(frame.loc[['a','c','d']]['Ohio'])
print(frame.loc[['a','c','d']][['Ohio','Texas']])
# Out:
#    Ohio  Texas  California
# a     0      1           2
# c     3      4           5
# d     6      7           8
# a    0
# c    3
# d    6
# Name: Ohio, dtype: int64
# <class 'pandas.core.series.Series'>
# Ohio          0
# Texas         1
# California    2
# Name: a, dtype: int64
# <class 'pandas.core.series.Series'>
# 0
#    Ohio  Texas  California
# a     0      1           2
# c     3      4           5
# d     6      7           8
# <class 'pandas.core.frame.DataFrame'>
# a    0
# c    3
# d    6
# Name: Ohio, dtype: int64
#    Ohio  Texas
# a     0      1
# c     3      4
# d     6      7

# %%
print(frame)
print(frame.loc[['a','c','d']]) # 명시적 index
print(frame.iloc[[0,1,2]])

print(frame.loc[['a','c','d']][['Ohio','Texas']]) # 명시적 index , dataFrame 비추
# print(frame.iloc[[0,1,2]][[0,1]]) # 암시적 index

# 강추 : [행, 열]
print(frame.loc[['a','c','d'], ['Ohio','Texas']]) # 행열
print(frame.iloc[[0,1,2], [0,1]]) # 행열
# Out:
#    Ohio  Texas  California
# a     0      1           2
# c     3      4           5
# d     6      7           8
#    Ohio  Texas  California
# a     0      1           2
# c     3      4           5
# d     6      7           8
#    Ohio  Texas  California
# a     0      1           2
# c     3      4           5
# d     6      7           8
#    Ohio  Texas
# a     0      1
# c     3      4
# d     6      7
#    Ohio  Texas
# a     0      1
# c     3      4
# d     6      7
#    Ohio  Texas
# a     0      1
# c     3      4
# d     6      7

# %%
# 항목 삭제
obj = pd.Series(np.arange(5.), index=["a", "b", "c", "d", "e"])
print(obj)
new_obj = obj.drop("c") # drop함수를 이용해서 해당 index를 삭제할 수 있다.
print(new_obj)
new_obj = obj.drop(["d", "c"])
print(new_obj)
# Out:
# a    0.0
# b    1.0
# c    2.0
# d    3.0
# e    4.0
# dtype: float64
# a    0.0
# b    1.0
# d    3.0
# e    4.0
# dtype: float64
# a    0.0
# b    1.0
# e    4.0
# dtype: float64

# %%
data = pd.DataFrame(np.arange(16).reshape((4, 4)),
                    index=["Ohio", "Colorado", "Utah", "New York"],
                    columns=["one", "two", "three", "four"])
data
# Out:
#           one  two  three  four
# Ohio        0    1      2     3
# Colorado    4    5      6     7
# Utah        8    9     10    11
# New York   12   13     14    15

# %%
new_data = data.drop(index=["Colorado", "Ohio"]) # DataFrame에서는 행당 index행을 삭제할 수 있다.
print(new_data)
new_data = data.drop(columns=["two"]) # columns 키워드를 이용하여 컬럼을 삭제
print(new_data)
new_data = data.drop("two", axis=1)  # axis=1은 열을 의미 한다. (행기준, y축기준)
print(new_data)
new_data = data.drop(["two", "four"], axis="columns")
print(new_data)
new_data = data.drop(["Ohio", "Colorado"], axis=0) #  axis=0은 행을 의미 (열 기준 , x축 기준)
print(new_data)
new_data = data.drop(["Ohio", "Colorado"], axis="index") #  axis=0은 행을 의미 (열 기준 , x축 기준)
print(new_data)
# Out:
#           one  two  three  four
# Utah        8    9     10    11
# New York   12   13     14    15
#           one  three  four
# Ohio        0      2     3
# Colorado    4      6     7
# Utah        8     10    11
# New York   12     14    15
#           one  three  four
# Ohio        0      2     3
# Colorado    4      6     7
# Utah        8     10    11
# New York   12     14    15
#           one  three
# Ohio        0      2
# Colorado    4      6
# Utah        8     10
# New York   12     14
#           one  two  three  four
# Utah        8    9     10    11
# New York   12   13     14    15
#           one  two  three  four
# Utah        8    9     10    11
# New York   12   13     14    15

# %%
# Indexing, Selection, and Filtering
obj = pd.Series(np.arange(4.), index=["a", "b", "c", "d"])
print(obj)
print(obj["b"]) #명시적 index
print(obj[1]) # 암시적 index
print(obj[2:4]) # 암시적 index를 이용한 slicing
print(obj[["b", "a", "d"]]) # 명시적
print(obj[[1, 3]]) # 암시적
print(obj[obj < 2]) # 부울 index
# Out:
# a    0.0
# b    1.0
# c    2.0
# d    3.0
# dtype: float64
# 1.0
# 1.0
# c    2.0
# d    3.0
# dtype: float64
# b    1.0
# a    0.0
# d    3.0
# dtype: float64
# b    1.0
# d    3.0
# dtype: float64
# a    0.0
# b    1.0
# dtype: float64
# /tmp/ipython-input-2116006461.py:5: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   print(obj[1])
# /tmp/ipython-input-2116006461.py:8: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   print(obj[[1, 3]])

# %%
print(obj)
print(obj.loc[["b", "a", "d"]]) # Series에서 loc사용
print(obj.iloc[[1,0,2]])
print(obj.loc["b":"c"]) # 명시적index :  b부터 c까지
print(obj.iloc[1:3]) # 암시적 index :  1부터 3전까지
obj.iloc[1:3] = 5
print(obj)
# Out:
# a    0.0
# b    1.0
# c    2.0
# d    3.0
# dtype: float64
# b    1.0
# a    0.0
# d    3.0
# dtype: float64
# b    1.0
# a    0.0
# c    2.0
# dtype: float64
# b    1.0
# c    2.0
# dtype: float64
# b    1.0
# c    2.0
# dtype: float64
# a    0.0
# b    5.0
# c    5.0
# d    3.0
# dtype: float64

# %%
data = pd.DataFrame(np.arange(16).reshape((4, 4)),
                    index=["Ohio", "Colorado", "Utah", "New York"],
                    columns=["one", "two", "three", "four"])
print(data)
print(data["two"]) # 열이름으로 데이터 가져오기
print(data[["three", "one"]])
print(data[:2]) # 암시적 index를 사용해서 행 값을 출럭
print(data.iloc[:2]) # 암시적 index를 사용해서 행 값을 출럭
print(data[data["three"] > 5])
data[data < 5] = 0
print(data)
print(data.loc["Colorado"] )
print(data.loc[["Colorado", "New York"]])
print(data.loc['Colorado',["two", "three"]])
# loc, iloc로 데이터를 가져 올 때는  행열로 가져운다.
# Out:
#           one  two  three  four
# Ohio        0    1      2     3
# Colorado    4    5      6     7
# Utah        8    9     10    11
# New York   12   13     14    15
# Ohio         1
# Colorado     5
# Utah         9
# New York    13
# Name: two, dtype: int64
#           three  one
# Ohio          2    0
# Colorado      6    4
# Utah         10    8
# New York     14   12
#           one  two  three  four
# Ohio        0    1      2     3
# Colorado    4    5      6     7
#           one  two  three  four
# Ohio        0    1      2     3
# Colorado    4    5      6     7
#           one  two  three  four
# Colorado    4    5      6     7
# Utah        8    9     10    11
# New York   12   13     14    15
#           one  two  three  four
# Ohio        0    0      0     0
# Colorado    0    5      6     7
# Utah        8    9     10    11
# New York   12   13     14    15
# one      0
# two      5
# three    6
# four     7
# Name: Colorado, dtype: int64
#           one  two  three  four
# Colorado    0    5      6     7
# New York   12   13     14    15
# two      5
# three    6
# Name: Colorado, dtype: int64

# %%
print(data)
print(data.iloc[2]) # 암시적 사용
print(data.iloc[[2, 1]])
print(data.iloc[2, [3, 0, 1]])
print(data.iloc[[1, 2], [3, 0, 1]])
print(data.iloc[:, :3][data.three > 5])
data.loc[data.three >= 2]
# Out:
#           one  two  three  four
# Ohio        0    0      0     0
# Colorado    0    5      6     7
# Utah        8    9     10    11
# New York   12   13     14    15
# one       8
# two       9
# three    10
# four     11
# Name: Utah, dtype: int64
#           one  two  three  four
# Utah        8    9     10    11
# Colorado    0    5      6     7
# four    11
# one      8
# two      9
# Name: Utah, dtype: int64
#           four  one  two
# Colorado     7    0    5
# Utah        11    8    9
#           one  two  three
# Colorado    0    5      6
# Utah        8    9     10
# New York   12   13     14
#           one  two  three  four
# Colorado    0    5      6     7
# Utah        8    9     10    11
# New York   12   13     14    15

# %%
ser = pd.Series(np.arange(3.))
print(ser)
print(ser[0])
# print(ser[-1])
print(ser.iloc[-1])
# Out:
# 0    0.0
# 1    1.0
# 2    2.0
# dtype: float64
# 0.0
# 2.0

# %%
# 산술 연산과 데이터 정렬
s1 = pd.Series([7.3, -2.5, 3.4, 1.5], index=["a", "c", "d", "e"])
s2 = pd.Series([-2.1, 3.6, -1.5, 4, 3.1],
               index=["a", "c", "e", "f", "g"])
s1, s2
# Out:
# (a    7.3
#  c   -2.5
#  d    3.4
#  e    1.5
#  dtype: float64,
#  a   -2.1
#  c    3.6
#  e   -1.5
#  f    4.0
#  g    3.1
#  dtype: float64)

# %%
s1 + s2 # index가 없으면 index를 맞추기 위해 브로드케스트를 하는데 브로드케스트된 index는 NaN값을 갖느다
# Out:
# a    5.2
# c    1.1
# d    NaN
# e    0.0
# f    NaN
# g    NaN
# dtype: float64

# %%
df1 = pd.DataFrame(np.arange(9.).reshape((3, 3)), columns=list("bcd"),
                   index=["Ohio", "Texas", "Colorado"])
df2 = pd.DataFrame(np.arange(12.).reshape((4, 3)), columns=list("bde"),
                   index=["Utah", "Ohio", "Texas", "Oregon"])
df1, df2
# Out:
# (            b    c    d
#  Ohio      0.0  1.0  2.0
#  Texas     3.0  4.0  5.0
#  Colorado  6.0  7.0  8.0,
#            b     d     e
#  Utah    0.0   1.0   2.0
#  Ohio    3.0   4.0   5.0
#  Texas   6.0   7.0   8.0
#  Oregon  9.0  10.0  11.0)

# %%
df1 + df2 # 행과 열이 같은 것 끼리의 연산이므로 크기가 다르면 브로드케스트를 해서 행과 열을 맞춰준다
# Out:
#             b   c     d   e
# Colorado  NaN NaN   NaN NaN
# Ohio      3.0 NaN   6.0 NaN
# Oregon    NaN NaN   NaN NaN
# Texas     9.0 NaN  12.0 NaN
# Utah      NaN NaN   NaN NaN

# %%
df1 = pd.DataFrame({"A": [1, 2]})
df2 = pd.DataFrame({"B": [3, 4]})
print(df1)
print(df2)
print(df1 + df2)
# Out:
#    A
# 0  1
# 1  2
#    B
# 0  3
# 1  4
#     A   B
# 0 NaN NaN
# 1 NaN NaN

# %%
# 결측값 채움을 활용한 산술 연산 메서드
df1 = pd.DataFrame(np.arange(12.).reshape((3, 4)),
                   columns=list("abcd"))
df2 = pd.DataFrame(np.arange(20.).reshape((4, 5)),
                   columns=list("abcde"))
print(df2)
df2.loc[1, "b"] = np.nan
print(df1)
print(df2)
# Out:
#       a     b     c     d     e
# 0   0.0   1.0   2.0   3.0   4.0
# 1   5.0   6.0   7.0   8.0   9.0
# 2  10.0  11.0  12.0  13.0  14.0
# 3  15.0  16.0  17.0  18.0  19.0
#      a    b     c     d
# 0  0.0  1.0   2.0   3.0
# 1  4.0  5.0   6.0   7.0
# 2  8.0  9.0  10.0  11.0
#       a     b     c     d     e
# 0   0.0   1.0   2.0   3.0   4.0
# 1   5.0   NaN   7.0   8.0   9.0
# 2  10.0  11.0  12.0  13.0  14.0
# 3  15.0  16.0  17.0  18.0  19.0

# %%
print(df1 + df2)
print(df1.add(df2))
print(df1.add(df2, fill_value=0))
# Out:
#       a     b     c     d   e
# 0   0.0   2.0   4.0   6.0 NaN
# 1   9.0   NaN  13.0  15.0 NaN
# 2  18.0  20.0  22.0  24.0 NaN
# 3   NaN   NaN   NaN   NaN NaN
#       a     b     c     d   e
# 0   0.0   2.0   4.0   6.0 NaN
# 1   9.0   NaN  13.0  15.0 NaN
# 2  18.0  20.0  22.0  24.0 NaN
# 3   NaN   NaN   NaN   NaN NaN
#       a     b     c     d     e
# 0   0.0   2.0   4.0   6.0   4.0
# 1   9.0   5.0  13.0  15.0   9.0
# 2  18.0  20.0  22.0  24.0  14.0
# 3  15.0  16.0  17.0  18.0  19.0

# %%
frame = pd.DataFrame(np.arange(12.).reshape((4, 3)),
                     columns=list("bde"),
                     index=["Utah", "Ohio", "Texas", "Oregon"])
series = frame.iloc[0]
print(frame)
print(series) # Series의 index는 DataFrame과 연산 경우 column명 으로 간주
'''
         b     d     e     -     b     d     e
Utah    0.0   1.0   2.0         0.0   1.0   2.0
Ohio    3.0   4.0   5.0         0.0   1.0   2.0
Texas   6.0   7.0   8.0         0.0   1.0   2.0
Oregon  9.0  10.0  11.0         0.0   1.0   2.0
'''
# Out:
#           b     d     e
# Utah    0.0   1.0   2.0
# Ohio    3.0   4.0   5.0
# Texas   6.0   7.0   8.0
# Oregon  9.0  10.0  11.0
# b    0.0
# d    1.0
# e    2.0
# Name: Utah, dtype: float64

# %%
frame - series
# Out:
#           b    d    e
# Utah    0.0  0.0  0.0
# Ohio    3.0  3.0  3.0
# Texas   6.0  6.0  6.0
# Oregon  9.0  9.0  9.0

# %%
series2 = pd.Series(np.arange(3), index=["b", "e", "f"])
print(series2)
print(frame)
'''
         b     d     e    f     +    b   e  f   d
Utah    0.0   1.0   2.0   NaN       0    1  2  NaN
Ohio    3.0   4.0   5.0   NaN       0    1  2  NaN
Texas   6.0   7.0   8.0   NaN       0    1  2  NaN
Oregon  9.0  10.0  11.0   NaN       0    1  2  NaN
'''
print(frame + series2)
print(frame.add(series2, axis="columns"))
# Out:
# b    0
# e    1
# f    2
# dtype: int64
#           b     d     e
# Utah    0.0   1.0   2.0
# Ohio    3.0   4.0   5.0
# Texas   6.0   7.0   8.0
# Oregon  9.0  10.0  11.0
#           b   d     e   f
# Utah    0.0 NaN   3.0 NaN
# Ohio    3.0 NaN   6.0 NaN
# Texas   6.0 NaN   9.0 NaN
# Oregon  9.0 NaN  12.0 NaN
#           b   d     e   f
# Utah    0.0 NaN   3.0 NaN
# Ohio    3.0 NaN   6.0 NaN
# Texas   6.0 NaN   9.0 NaN
# Oregon  9.0 NaN  12.0 NaN

# %%
series3 = frame["d"]
print(frame)
print(series3)
print(frame.add(series3, axis='index'))
# Out:
#           b     d     e
# Utah    0.0   1.0   2.0
# Ohio    3.0   4.0   5.0
# Texas   6.0   7.0   8.0
# Oregon  9.0  10.0  11.0
# Utah       1.0
# Ohio       4.0
# Texas      7.0
# Oregon    10.0
# Name: d, dtype: float64
#            b     d     e
# Utah     1.0   2.0   3.0
# Ohio     7.0   8.0   9.0
# Texas   13.0  14.0  15.0
# Oregon  19.0  20.0  21.0

# %%
# 정렬
obj = pd.Series([4, 7, -3, 2])
print(obj)
print(obj.sort_values())
# Out:
# 0    4
# 1    7
# 2   -3
# 3    2
# dtype: int64
# 2   -3
# 3    2
# 0    4
# 1    7
# dtype: int64

# %%
obj = pd.Series([4, np.nan, 7, np.nan, -3, 2])
obj.sort_values()
obj.sort_values(na_position="first")
# Out:
# 1    NaN
# 3    NaN
# 4   -3.0
# 5    2.0
# 0    4.0
# 2    7.0
# dtype: float64

# %%
obj = pd.Series(np.arange(4), index=["d", "a", "b", "c"])
print(obj)
obj1 = obj.sort_index() # index 정렬
print(obj1)
# Out:
# d    0
# a    1
# b    2
# c    3
# dtype: int64
# a    1
# b    2
# c    3
# d    0
# dtype: int64

# %%
frame = pd.DataFrame(np.arange(8).reshape((2, 4)),
                     index=["three", "one"],
                     columns=["d", "a", "b", "c"])
print(frame)
print(frame.sort_index())
print(frame.sort_index(axis="columns"))
print(frame.sort_index(axis=1))
print(frame.sort_index(axis="columns", ascending=False))
print(frame.sort_values('b'))
print(frame.sort_values(['a', 'b']))
# Out:
#        d  a  b  c
# three  0  1  2  3
# one    4  5  6  7
#        d  a  b  c
# one    4  5  6  7
# three  0  1  2  3
#        a  b  c  d
# three  1  2  3  0
# one    5  6  7  4
#        a  b  c  d
# three  1  2  3  0
# one    5  6  7  4
#        d  c  b  a
# three  0  3  2  1
# one    4  7  6  5
#        d  a  b  c
# three  0  1  2  3
# one    4  5  6  7
#        d  a  b  c
# three  0  1  2  3
# one    4  5  6  7

# %%
frame = pd.DataFrame(np.arange(12.).reshape((4, 3)),
                     columns=list("bde"),
                     index=["Utah", "Ohio", "Texas", "Oregon"])
print(frame)
print(frame.sum())
print(frame.sum(axis = 'index'))
print(frame.sum(axis = 'columns'))
# Out:
#           b     d     e
# Utah    0.0   1.0   2.0
# Ohio    3.0   4.0   5.0
# Texas   6.0   7.0   8.0
# Oregon  9.0  10.0  11.0
# b    18.0
# d    22.0
# e    26.0
# dtype: float64
# b    18.0
# d    22.0
# e    26.0
# dtype: float64
# Utah       3.0
# Ohio      12.0
# Texas     21.0
# Oregon    30.0
# dtype: float64

# %%
print(frame.mean()) # axis='index'가 생략되었다.
print(frame.mean(axis='index'))
print(frame.mean(axis='columns'))
# Out:
# b    4.5
# d    5.5
# e    6.5
# dtype: float64
# b    4.5
# d    5.5
# e    6.5
# dtype: float64
# Utah       1.0
# Ohio       4.0
# Texas      7.0
# Oregon    10.0
# dtype: float64

# %%
print(frame.cumsum())
print(frame.cumsum(axis='index'))
print(frame.cumsum(axis='columns'))
# Out:
#            b     d     e
# Utah     0.0   1.0   2.0
# Ohio     3.0   5.0   7.0
# Texas    9.0  12.0  15.0
# Oregon  18.0  22.0  26.0
#            b     d     e
# Utah     0.0   1.0   2.0
# Ohio     3.0   5.0   7.0
# Texas    9.0  12.0  15.0
# Oregon  18.0  22.0  26.0
#           b     d     e
# Utah    0.0   1.0   3.0
# Ohio    3.0   7.0  12.0
# Texas   6.0  13.0  21.0
# Oregon  9.0  19.0  30.0

# %%
frame.describe()
# Out:
#               b          d          e
# count  4.000000   4.000000   4.000000
# mean   4.500000   5.500000   6.500000
# std    3.872983   3.872983   3.872983
# min    0.000000   1.000000   2.000000
# 25%    2.250000   3.250000   4.250000
# 50%    4.500000   5.500000   6.500000
# 75%    6.750000   7.750000   8.750000
# max    9.000000  10.000000  11.000000

# %%
obj = pd.Series(["a", "a", "b", "c"] * 4)
print(obj)
obj.describe()
# Out:
# 0     a
# 1     a
# 2     b
# 3     c
# 4     a
# 5     a
# 6     b
# 7     c
# 8     a
# 9     a
# 10    b
# 11    c
# 12    a
# 13    a
# 14    b
# 15    c
# dtype: object
# count     16
# unique     3
# top        a
# freq       8
# dtype: object

# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv("https://raw.githubusercontent.com/SoongMoo/data-analysis/refs/heads/main/examples/ex1.csv")
df
# Out:
#    a   b   c   d message
# 0  1   2   3   4   hello
# 1  5   6   7   8   world
# 2  9  10  11  12     foo

# %%
df = pd.read_csv("https://raw.githubusercontent.com/SoongMoo/data-analysis/refs/heads/main/examples/ex1.csv",  header=None)
df
# Out:
#    0   1   2   3        4
# 0  a   b   c   d  message
# 1  1   2   3   4    hello
# 2  5   6   7   8    world
# 3  9  10  11  12      foo

# %%
df= pd.read_csv("https://raw.githubusercontent.com/SoongMoo/data-analysis/refs/heads/main/examples/ex3.txt", sep=r"\s+")
df
# Out:
#             A         B         C
# aaa -0.264438 -1.026059 -0.619500
# bbb  0.927272  0.302904 -0.032399
# ccc -0.264273 -0.386314 -0.217601
# ddd -0.871858 -0.348382  1.100491

# %%
df=pd.read_csv("https://raw.githubusercontent.com/SoongMoo/data-analysis/refs/heads/main/examples/ex4.csv", skiprows=[0, 2, 3])
df
# Out:
#    a   b   c   d message
# 0  1   2   3   4   hello
# 1  5   6   7   8   world
# 2  9  10  11  12     foo

# %%
df = pd.read_csv("https://raw.githubusercontent.com/SoongMoo/data-analysis/refs/heads/main/examples/ex5.csv")
df
# Out:
#   something  a   b     c   d message
# 0       one  1   2   3.0   4     NaN
# 1       two  5   6   NaN   8   world
# 2     three  9  10  11.0  12     foo

# %%
# NaN이면 True, 아니면 False
pd.isna(df)
# Out:
#    something      a      b      c      d  message
# 0      False  False  False  False  False     True
# 1      False  False  False   True  False    False
# 2      False  False  False  False  False    False

# %%
df = pd.read_csv("https://raw.githubusercontent.com/SoongMoo/data-analysis/refs/heads/main/examples/ex5.csv"
                , na_values=["NULL", "NA", "-", ""])
df
# Out:
#   something  a   b     c   d message
# 0       one  1   2   3.0   4     NaN
# 1       two  5   6   NaN   8   world
# 2     three  9  10  11.0  12     foo

# %%
df = pd.read_csv("https://raw.githubusercontent.com/SoongMoo/data-analysis/refs/heads/main/examples/ex5.csv"
                , keep_default_na=False)
print(df)
df = pd.read_csv("https://raw.githubusercontent.com/SoongMoo/data-analysis/refs/heads/main/examples/ex5.csv"
                , keep_default_na=False, na_values=['NA'])
print(df)
# Out:
#   something  a   b   c   d message
# 0       one  1   2   3   4      NA
# 1       two  5   6       8   world
# 2     three  9  10  11  12     foo
#   something  a   b   c   d message
# 0       one  1   2   3   4     NaN
# 1       two  5   6       8   world
# 2     three  9  10  11  12     foo

# %%
sentinels = {"message": ["foo", "NA"], "something": ["two"]}
df = pd.read_csv("https://raw.githubusercontent.com/SoongMoo/data-analysis/refs/heads/main/examples/ex5.csv"
                , keep_default_na=False, na_values=sentinels)
df
# Out:
#   something  a   b   c   d message
# 0       one  1   2   3   4     NaN
# 1       NaN  5   6       8   world
# 2     three  9  10  11  12     NaN

# %%
df = pd.read_csv("https://raw.githubusercontent.com/SoongMoo/data-analysis/refs/heads/main/examples/ex6.csv")
print(df)
df = pd.read_csv("https://raw.githubusercontent.com/SoongMoo/data-analysis/refs/heads/main/examples/ex6.csv", nrows=5)
print(df)
df = pd.read_csv("https://raw.githubusercontent.com/SoongMoo/data-analysis/refs/heads/main/examples/ex6.csv", chunksize=1000)
print(df)
# Out:
#            one       two     three      four key
# 0     0.467976 -0.038649 -0.295344 -1.824726   L
# 1    -0.358893  1.404453  0.704965 -0.200638   B
# 2    -0.501840  0.659254 -0.421691 -0.057688   G
# 3     0.204886  1.074134  1.388361 -0.982404   R
# 4     0.354628 -0.133116  0.283763 -0.837063   Q
# ...        ...       ...       ...       ...  ..
# 9995  2.311896 -0.417070 -1.409599 -0.515821   L
# 9996 -0.479893 -0.650419  0.745152 -0.646038   E
# 9997  0.523331  0.787112  0.486066  1.093156   K
# 9998 -0.362559  0.598894 -1.843201  0.887292   G
# 9999 -0.096376 -1.012999 -0.657431 -0.573315   0
#
# [10000 rows x 5 columns]
#         one       two     three      four key
# 0  0.467976 -0.038649 -0.295344 -1.824726   L
# 1 -0.358893  1.404453  0.704965 -0.200638   B
# 2 -0.501840  0.659254 -0.421691 -0.057688   G
# 3  0.204886  1.074134  1.388361 -0.982404   R
# 4  0.354628 -0.133116  0.283763 -0.837063   Q
# <pandas.io.parsers.readers.TextFileReader object at 0x7b4c1270c740>

# %%
df = pd.read_csv("https://raw.githubusercontent.com/SoongMoo/data-analysis/refs/heads/main/examples/ex5.csv")
df
# Out:
#   something  a   b     c   d message
# 0       one  1   2   3.0   4     NaN
# 1       two  5   6   NaN   8   world
# 2     three  9  10  11.0  12     foo

# %%
df.shape
for i in range(df.shape[0]):
  print(df.iloc[i])
# Out:
# something    one
# a              1
# b              2
# c            3.0
# d              4
# message      NaN
# Name: 0, dtype: object
# something      two
# a                5
# b                6
# c              NaN
# d                8
# message      world
# Name: 1, dtype: object
# something    three
# a                9
# b               10
# c             11.0
# d               12
# message        foo
# Name: 2, dtype: object

# %%
df
# Out:
#   something  a   b     c   d message
# 0       one  1   2   3.0   4     NaN
# 1       two  5   6   NaN   8   world
# 2     three  9  10  11.0  12     foo

# %%
df.to_csv("ex5.csv")

# %%
import sys
df.to_csv("ex5.csv", na_rep="NULL")
df.to_csv(sys.stdout, na_rep="NULL")

# %%
import sys
df.to_csv("ex5.csv", index=False)

# %%
df.to_csv("ex5.csv", header=False)

# %%
df.to_csv("ex5.csv", index=False , header=False)

# %%
df.to_csv("ex5.csv", index=False , columns=["a", "b", "c"])

# %%
df = pd.read_json("https://raw.githubusercontent.com/SoongMoo/data-analysis/refs/heads/main/examples/example.json")
df
# Out:
#    a  b  c
# 0  1  2  3
# 1  4  5  6
# 2  7  8  9

# %%
perf2 = pd.read_xml("https://raw.githubusercontent.com/SoongMoo/data-analysis/refs/heads/main/datasets/mta_perf/Performance_MNR.xml")
perf2.head()
# Out:
#    INDICATOR_SEQ  PARENT_SEQ           AGENCY_NAME  \
# 0          28445         NaN  Metro-North Railroad
# 1          28445         NaN  Metro-North Railroad
# 2          28445         NaN  Metro-North Railroad
# 3          28445         NaN  Metro-North Railroad
# 4          28445         NaN  Metro-North Railroad
#
#                          INDICATOR_NAME  \
# 0  On-Time Performance (West of Hudson)
# 1  On-Time Performance (West of Hudson)
# 2  On-Time Performance (West of Hudson)
# 3  On-Time Performance (West of Hudson)
# 4  On-Time Performance (West of Hudson)
#
#                                          DESCRIPTION  PERIOD_YEAR  \
# 0  Percent of commuter trains that arrive at thei...         2008
# 1  Percent of commuter trains that arrive at thei...         2008
# 2  Percent of commuter trains that arrive at thei...         2008
# 3  Percent of commuter trains that arrive at thei...         2008
# 4  Percent of commuter trains that arrive at thei...         2008
#
#    PERIOD_MONTH            CATEGORY FREQUENCY DESIRED_CHANGE INDICATOR_UNIT  \
# 0             1  Service Indicators         M              U              %
# 1             2  Service Indicators         M              U              %
# 2             3  Service Indicators         M              U              %
# 3             4  Service Indicators         M              U              %
# 4             5  Service Indicators         M              U              %
#
#    DECIMAL_PLACES YTD_TARGET YTD_ACTUAL MONTHLY_TARGET MONTHLY_ACTUAL
# 0               1      95.00      96.90          95.00          96.90
# 1               1      95.00      96.00          95.00          95.00
# 2               1      95.00      96.30          95.00          96.90
# 3               1      95.00      96.80          95.00          98.30
# 4               1      95.00      96.60          95.00          95.80

# %%
df = pd.read_csv("https://raw.githubusercontent.com/SoongMoo/data-analysis/refs/heads/main/examples/ex1.csv")
df
df.to_pickle("frame_pickle")

# %%
df = pd.read_pickle("frame_pickle")
df
# Out:
#    a   b   c   d message
# 0  1   2   3   4   hello
# 1  5   6   7   8   world
# 2  9  10  11  12     foo

# %%
# 누락된 데이터 처리
data = pd.Series([1, np.nan, 3.5, np.nan, 7])
print(data)
print(data.isna())
print(data.dropna()) # 누락깂 제외하고 출력
print(data[data.notna()]) # 누락깂 제외하고 출력
# Out:
# 0    1.0
# 1    NaN
# 2    3.5
# 3    NaN
# 4    7.0
# dtype: float64
# 0    False
# 1     True
# 2    False
# 3     True
# 4    False
# dtype: bool
# 0    1.0
# 2    3.5
# 4    7.0
# dtype: float64
# 0    1.0
# 2    3.5
# 4    7.0
# dtype: float64

# %%
data = pd.DataFrame([[1., 6.5, 3.], [1., np.nan, np.nan],
                     [np.nan, np.nan, np.nan], [np.nan, 6.5, 3.]])
print(data)
print(data.dropna())
print(data.dropna(how="all")) # axis='index' 생략
print(data.dropna(how="all", axis='index'))  # index가 NaN일 때는 제거
print(data.dropna(how="all", axis='columns')) # 열의 값이 모두 NaN 인 경우에만 제거
# Out:
#      0    1    2
# 0  1.0  6.5  3.0
# 1  1.0  NaN  NaN
# 2  NaN  NaN  NaN
# 3  NaN  6.5  3.0
#      0    1    2
# 0  1.0  6.5  3.0
#      0    1    2
# 0  1.0  6.5  3.0
# 1  1.0  NaN  NaN
# 3  NaN  6.5  3.0
#      0    1    2
# 0  1.0  6.5  3.0
# 1  1.0  NaN  NaN
# 3  NaN  6.5  3.0
#      0    1    2
# 0  1.0  6.5  3.0
# 1  1.0  NaN  NaN
# 2  NaN  NaN  NaN
# 3  NaN  6.5  3.0

# %%
print(data)
print(data.dropna(how="any")) # index에 적어 하나가NaN라면 제거
print(data.dropna(how="any", axis='index'))
print(data.dropna(how="any", axis='columns'))
# Out:
#      0    1    2
# 0  1.0  6.5  3.0
# 1  1.0  NaN  NaN
# 2  NaN  NaN  NaN
# 3  NaN  6.5  3.0
#      0    1    2
# 0  1.0  6.5  3.0
#      0    1    2
# 0  1.0  6.5  3.0
# Empty DataFrame
# Columns: []
# Index: [0, 1, 2, 3]

# %%
print(data)
print(data.fillna(data.mean())) # 열의 평균값으로 채우기
print(data.fillna(method='ffill'))
print(data.fillna(method='bfill'))
print(data.fillna(method='bfill', limit=2)) # 연속된 NaN 값이 있을 때, 최대 2개까지만 앞의 값으로 채워줍니다
# Out:
#      0    1    2
# 0  1.0  6.5  3.0
# 1  1.0  NaN  NaN
# 2  NaN  NaN  NaN
# 3  NaN  6.5  3.0
#      0    1    2
# 0  1.0  6.5  3.0
# 1  1.0  6.5  3.0
# 2  1.0  6.5  3.0
# 3  1.0  6.5  3.0
#      0    1    2
# 0  1.0  6.5  3.0
# 1  1.0  6.5  3.0
# 2  1.0  6.5  3.0
# 3  1.0  6.5  3.0
#      0    1    2
# 0  1.0  6.5  3.0
# 1  1.0  6.5  3.0
# 2  NaN  6.5  3.0
# 3  NaN  6.5  3.0
#      0    1    2
# 0  1.0  6.5  3.0
# 1  1.0  6.5  3.0
# 2  NaN  6.5  3.0
# 3  NaN  6.5  3.0
# /tmp/ipython-input-824381844.py:3: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   print(data.fillna(method='ffill'))
# /tmp/ipython-input-824381844.py:4: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   print(data.fillna(method='bfill'))
# /tmp/ipython-input-824381844.py:5: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   print(data.fillna(method='bfill', limit=2)) # 연속된 NaN 값이 있을 때, 최대 2개까지만 앞의 값으로 채워줍니다

# %%
data = pd.DataFrame({"k1": ["one", "two"] * 3 + ["two"],
                     "k2": [1, 1, 2, 3, 3, 4, 4]})
print(data)
print(data.duplicated()) # Ture 이면 중복 , 부울 index
print(data[data.duplicated()]) # 중복된행 만 출역
# Out:
#     k1  k2
# 0  one   1
# 1  two   1
# 2  one   2
# 3  two   3
# 4  one   3
# 5  two   4
# 6  two   4
# 0    False
# 1    False
# 2    False
# 3    False
# 4    False
# 5    False
# 6     True
# dtype: bool
#     k1  k2
# 6  two   4

# %%
print(data)
data["v1"] = range(7)
print(data)
# Out:
#     k1  k2
# 0  one   1
# 1  two   1
# 2  one   2
# 3  two   3
# 4  one   3
# 5  two   4
# 6  two   4
#     k1  k2  v1
# 0  one   1   0
# 1  two   1   1
# 2  one   2   2
# 3  two   3   3
# 4  one   3   4
# 5  two   4   5
# 6  two   4   6

# %%
data.drop_duplicates(subset=["k1"])
data.drop_duplicates(subset=["k1", "k2"])
data.drop_duplicates(subset=["k1", "k2"], keep="last")
# Out:
#     k1  k2  v1
# 0  one   1   0
# 1  two   1   1
# 2  one   2   2
# 3  two   3   3
# 4  one   3   4
# 6  two   4   6

# %%
data = pd.Series([1., -999., 2., -999., -1000., 3.])
print(data)
print(data.replace(-999, np.nan))
print(data.replace([-999,-1000], np.nan))
print(data.replace([-999,-1000], [np.nan, 0]))
print(data.replace({-999 : np.nan, -1000: 0}))
# Out:
# 0       1.0
# 1    -999.0
# 2       2.0
# 3    -999.0
# 4   -1000.0
# 5       3.0
# dtype: float64
# 0       1.0
# 1       NaN
# 2       2.0
# 3       NaN
# 4   -1000.0
# 5       3.0
# dtype: float64
# 0    1.0
# 1    NaN
# 2    2.0
# 3    NaN
# 4    NaN
# 5    3.0
# dtype: float64
# 0    1.0
# 1    NaN
# 2    2.0
# 3    NaN
# 4    0.0
# 5    3.0
# dtype: float64

# %%
# 데이터 병합
site = pd.read_csv("https://raw.githubusercontent.com/SoongMoo/data-analysis/refs/heads/main/examples/survey_site.csv")
visited = pd.read_csv("https://raw.githubusercontent.com/SoongMoo/data-analysis/refs/heads/main/examples/survey_visited.csv")
person  = pd.read_csv("https://raw.githubusercontent.com/SoongMoo/data-analysis/refs/heads/main/examples/survey_person.csv")
survey = pd.read_csv("https://raw.githubusercontent.com/SoongMoo/data-analysis/refs/heads/main/examples/survey_survey.csv")
site, visited, survey, person
# Out:
# (    name    lat    long
#  0   DR-1 -49.85 -128.57
#  1   DR-3 -47.15 -126.72
#  2  MSK-4 -48.87 -123.40,
#     ident   site       dated
#  0    619   DR-1  1927-02-08
#  1    622   DR-1  1927-02-10
#  2    734   DR-3  1939-01-07
#  3    735   DR-3  1930-01-12
#  4    751   DR-3  1930-02-26
#  5    752   DR-3         NaN
#  6    837  MSK-4  1932-01-14
#  7    844   DR-1  1932-03-22,
#      taken person quant  reading
#  0     619   dyer   rad     9.82
#  1     619   dyer   sal     0.13
#  2     622   dyer   rad     7.80
#  3     622   dyer   sal     0.09
#  4     734     pb   rad     8.41
#  5     734   lake   sal     0.05
#  6     734     pb  temp   -21.50
#  7     735     pb   rad     7.22
#  8     735    NaN   sal     0.06
#  9     735    NaN  temp   -26.00
#  10    751     pb   rad     4.35
#  11    751     pb  temp   -18.50
#  12    751   lake   sal     0.10
#  13    752   lake   rad     2.19
#  14    752   lake   sal     0.09
#  15    752   lake  temp   -16.00
#  16    752    roe   sal    41.60
#  17    837   lake   rad     1.46
#  18    837   lake   sal     0.21
#  19    837    roe   sal    22.50
#  20    844    roe   rad    11.25,
#        ident   personal    family
#  0      dyer    William      Dyer
#  1        pb      Frank   Pabodie
#  2      lake   Anderson      Lake
#  3       roe  Valentina   Roerich
#  4  danforth      Frank  Danforth)

# %%
site_visited = site.merge(visited, left_on = 'name' , right_on  = 'site')
site_visited
# Out:
#     name    lat    long  ident   site       dated
# 0   DR-1 -49.85 -128.57    619   DR-1  1927-02-08
# 1   DR-1 -49.85 -128.57    622   DR-1  1927-02-10
# 2   DR-1 -49.85 -128.57    844   DR-1  1932-03-22
# 3   DR-3 -47.15 -126.72    734   DR-3  1939-01-07
# 4   DR-3 -47.15 -126.72    735   DR-3  1930-01-12
# 5   DR-3 -47.15 -126.72    751   DR-3  1930-02-26
# 6   DR-3 -47.15 -126.72    752   DR-3         NaN
# 7  MSK-4 -48.87 -123.40    837  MSK-4  1932-01-14

# %%
person ,survey
person_survey = person.merge(survey ,left_on ='ident' , right_on = 'person')
person_survey
# Out:
#    ident   personal   family  taken person quant  reading
# 0   dyer    William     Dyer    619   dyer   rad     9.82
# 1   dyer    William     Dyer    619   dyer   sal     0.13
# 2   dyer    William     Dyer    622   dyer   rad     7.80
# 3   dyer    William     Dyer    622   dyer   sal     0.09
# 4     pb      Frank  Pabodie    734     pb   rad     8.41
# 5     pb      Frank  Pabodie    734     pb  temp   -21.50
# 6     pb      Frank  Pabodie    735     pb   rad     7.22
# 7     pb      Frank  Pabodie    751     pb   rad     4.35
# 8     pb      Frank  Pabodie    751     pb  temp   -18.50
# 9   lake   Anderson     Lake    734   lake   sal     0.05
# 10  lake   Anderson     Lake    751   lake   sal     0.10
# 11  lake   Anderson     Lake    752   lake   rad     2.19
# 12  lake   Anderson     Lake    752   lake   sal     0.09
# 13  lake   Anderson     Lake    752   lake  temp   -16.00
# 14  lake   Anderson     Lake    837   lake   rad     1.46
# 15  lake   Anderson     Lake    837   lake   sal     0.21
# 16   roe  Valentina  Roerich    752    roe   sal    41.60
# 17   roe  Valentina  Roerich    837    roe   sal    22.50
# 18   roe  Valentina  Roerich    844    roe   rad    11.25

# %%
# 누락된 데이터 출력
person_survey = person.merge(survey ,left_on ='ident' , right_on = 'person', how = 'left')
person_survey
# how : left, right, inner, outer

# %%
#DataFrame 합치기
df11 = pd.read_csv("https://raw.githubusercontent.com/SoongMoo/data-analysis/refs/heads/main/examples/concat_1.csv")
df12 = pd.read_csv("https://raw.githubusercontent.com/SoongMoo/data-analysis/refs/heads/main/examples/concat_2.csv")
df13 = pd.read_csv("https://raw.githubusercontent.com/SoongMoo/data-analysis/refs/heads/main/examples/concat_3.csv")
df11, df12, df13
# Out:
# (    A   B   C   D
#  0  a0  b0  c0  d0
#  1  a1  b1  c1  d1
#  2  a2  b2  c2  d2
#  3  a3  b3  c3  d3,
#      A   B   C   D
#  0  a4  b4  c4  d4
#  1  a5  b5  c5  d5
#  2  a6  b6  c6  d6
#  3  a7  b7  c7  d7,
#       A    B    C    D
#  0   a8   b8   c8   d8
#  1   a9   b9   c9   d9
#  2  a10  b10  c10  d10
#  3  a11  b11  c11  d11)

# %%
row_concat = pd.concat([df11, df12,df13])
row_concat
row_concat = pd.concat([df11, df12,df13], axis = 0 ) # 열기준
row_concat
row_concat = pd.concat([df11, df12,df13], axis = 'index' ) # 열기준
row_concat
# Out:
#      A    B    C    D
# 0   a0   b0   c0   d0
# 1   a1   b1   c1   d1
# 2   a2   b2   c2   d2
# 3   a3   b3   c3   d3
# 0   a4   b4   c4   d4
# 1   a5   b5   c5   d5
# 2   a6   b6   c6   d6
# 3   a7   b7   c7   d7
# 0   a8   b8   c8   d8
# 1   a9   b9   c9   d9
# 2  a10  b10  c10  d10
# 3  a11  b11  c11  d11

# %%
col_concat = pd.concat([df11, df12,df13], axis = 1 ) # 행기준
col_concat
col_concat = pd.concat([df11, df12,df13], axis = 'columns' ) # 행기준
col_concat
# Out:
#     A   B   C   D   A   B   C   D    A    B    C    D
# 0  a0  b0  c0  d0  a4  b4  c4  d4   a8   b8   c8   d8
# 1  a1  b1  c1  d1  a5  b5  c5  d5   a9   b9   c9   d9
# 2  a2  b2  c2  d2  a6  b6  c6  d6  a10  b10  c10  d10
# 3  a3  b3  c3  d3  a7  b7  c7  d7  a11  b11  c11  d11

# %%
df14 = pd.DataFrame({'A':['n1','n2','n3'],
                     'C':['n11','n12','n13'],
                     'E':['n21','n22','n23'],
                     'F':['n31','n32','n33']},
                     index=[0,2,4])
df14
# Out:
#     A    C    E    F
# 0  n1  n11  n21  n31
# 2  n2  n12  n22  n32
# 4  n3  n13  n23  n33

# %%
df11_df14_row_concat = pd.concat([df11, df14], axis=0)
df11_df14_row_concat
# Out:
#     A    B    C    D    E    F
# 0  a0   b0   c0   d0  NaN  NaN
# 1  a1   b1   c1   d1  NaN  NaN
# 2  a2   b2   c2   d2  NaN  NaN
# 3  a3   b3   c3   d3  NaN  NaN
# 0  n1  NaN  n11  NaN  n21  n31
# 2  n2  NaN  n12  NaN  n22  n32
# 4  n3  NaN  n13  NaN  n23  n33

# %%
df11_df14_col_concat = pd.concat([df11, df14], axis=1)
df11_df14_col_concat
# Out:
#      A    B    C    D    A    C    E    F
# 0   a0   b0   c0   d0   n1  n11  n21  n31
# 1   a1   b1   c1   d1  NaN  NaN  NaN  NaN
# 2   a2   b2   c2   d2   n2  n12  n22  n32
# 3   a3   b3   c3   d3  NaN  NaN  NaN  NaN
# 4  NaN  NaN  NaN  NaN   n3  n13  n23  n33

# %%
# Series와 DataFrame을 합치기
new_row_series = pd.Series(['n1', 'n2', 'n3', 'n4'])
df11, new_row_series
df11_series_col = pd.concat([df11, new_row_series], axis=1 )
df11_series_col
df11_series_col = pd.concat([df11, new_row_series], axis=0 )
df11_series_col
# Out:
#      A    B    C    D    0
# 0   a0   b0   c0   d0  NaN
# 1   a1   b1   c1   d1  NaN
# 2   a2   b2   c2   d2  NaN
# 3   a3   b3   c3   d3  NaN
# 0  NaN  NaN  NaN  NaN   n1
# 1  NaN  NaN  NaN  NaN   n2
# 2  NaN  NaN  NaN  NaN   n3
# 3  NaN  NaN  NaN  NaN   n4

# %%
# 열이름 변경하기
df12.columns=['E','F','G','H']
df13.columns=['A','C','F','H']
df11,df12,df13
# Out:
# (    A   B   C   D
#  0  a0  b0  c0  d0
#  1  a1  b1  c1  d1
#  2  a2  b2  c2  d2
#  3  a3  b3  c3  d3,
#      E   F   G   H
#  0  a4  b4  c4  d4
#  1  a5  b5  c5  d5
#  2  a6  b6  c6  d6
#  3  a7  b7  c7  d7,
#       A    C    F    H
#  0   a8   b8   c8   d8
#  1   a9   b9   c9   d9
#  2  a10  b10  c10  d10
#  3  a11  b11  c11  d11)

# %%
row_concat2  = pd.concat([df11,df12,df13], axis=0) # 열기준
row_concat2
# 누락값이 없는 열만 출력
row_concat2  = pd.concat([df11,df12,df13], axis=0, join = 'inner')
row_concat2
df16 = pd.concat([df11,df13], axis=0 )
df16
df16 = pd.concat([df11,df13], axis=0 , join = 'inner')
df16
df16.loc[0]
df16 = pd.concat([df11,df13], axis=0 , join = 'inner', ignore_index=True) # 행번호 무시
df16
# Out:
#      A    C
# 0   a0   c0
# 1   a1   c1
# 2   a2   c2
# 3   a3   c3
# 4   a8   b8
# 5   a9   b9
# 6  a10  b10
# 7  a11  b11

# %%
df12,df13
df12.index = [4,5,6,7]
df13.index = [0,2,5,7]
df11, df12, df13
# Out:
# (    A   B   C   D
#  0  a0  b0  c0  d0
#  1  a1  b1  c1  d1
#  2  a2  b2  c2  d2
#  3  a3  b3  c3  d3,
#      E   F   G   H
#  4  a4  b4  c4  d4
#  5  a5  b5  c5  d5
#  6  a6  b6  c6  d6
#  7  a7  b7  c7  d7,
#       A    C    F    H
#  0   a8   b8   c8   d8
#  2   a9   b9   c9   d9
#  5  a10  b10  c10  d10
#  7  a11  b11  c11  d11)

# %%
df17 = pd.concat([df12, df13], axis=1)
df17
df17 = pd.concat([df12, df13], axis=1  , join = 'inner')
df17
df17 = pd.concat([df12, df13], axis=1  , join = 'inner', ignore_index=True) # 열이름 무시
df17
# Out:
#     0   1   2   3    4    5    6    7
# 5  a5  b5  c5  d5  a10  b10  c10  d10
# 7  a7  b7  c7  d7  a11  b11  c11  d11

# %%
# group by
df = pd.read_csv("https://raw.githubusercontent.com/SoongMoo/data-analysis/refs/heads/main/examples/gapminder.tsv"
                 , sep="\t")
df
# Out:
#           country continent  year  lifeExp       pop   gdpPercap
# 0     Afghanistan      Asia  1952   28.801   8425333  779.445314
# 1     Afghanistan      Asia  1957   30.332   9240934  820.853030
# 2     Afghanistan      Asia  1962   31.997  10267083  853.100710
# 3     Afghanistan      Asia  1967   34.020  11537966  836.197138
# 4     Afghanistan      Asia  1972   36.088  13079460  739.981106
# ...           ...       ...   ...      ...       ...         ...
# 1699     Zimbabwe    Africa  1987   62.351   9216418  706.157306
# 1700     Zimbabwe    Africa  1992   60.377  10704340  693.420786
# 1701     Zimbabwe    Africa  1997   46.809  11404948  792.449960
# 1702     Zimbabwe    Africa  2002   39.989  11926563  672.038623
# 1703     Zimbabwe    Africa  2007   43.487  12311143  469.709298
#
# [1704 rows x 6 columns]

# %%
  df.groupby('year')['lifeExp'].mean()
  df.groupby('year').lifeExp.min()
  df.groupby('year')['gdpPercap'].mean()
  df.groupby('year').gdpPercap.max()
# Out:
# year
# 1952    108382.35290
# 1957    113523.13290
# 1962     95458.11176
# 1967     80894.88326
# 1972    109347.86700
# 1977     59265.47714
# 1982     33693.17525
# 1987     31540.97480
# 1992     34932.91959
# 1997     41283.16433
# 2002     44683.97525
# 2007     49357.19017
# Name: gdpPercap, dtype: float64

# %%
df
df.groupby(['continent', 'country']).lifeExp.mean()
df.groupby(['continent', 'country']).lifeExp.min()
df.groupby(['continent', 'country']).lifeExp.max()
df.groupby(['year', 'continent'])[['lifeExp','gdpPercap']].min()
## 대륙에 대한 나라의 갯수
df.groupby('continent')['country'].nunique()
# Out:
# continent
# Africa      52
# Americas    25
# Asia        33
# Europe      30
# Oceania      2
# Name: country, dtype: int64

# %%
# 년도에 따른 평균수명의  평균의 추이를 확인
import matplotlib as plt

df.groupby('year').lifeExp.mean().plot()
# Out:
# <Axes: xlabel='year'>

# %%
df.groupby('year').gdpPercap.mean().plot()
# Out:
# <Axes: xlabel='year'>

# %%
# !pip install seaborn # 타이타닉
# Out:
# Requirement already satisfied: seaborn in /usr/local/lib/python3.12/dist-packages (0.13.2)
# Requirement already satisfied: numpy!=1.24.0,>=1.20 in /usr/local/lib/python3.12/dist-packages (from seaborn) (2.0.2)
# Requirement already satisfied: pandas>=1.2 in /usr/local/lib/python3.12/dist-packages (from seaborn) (2.2.2)
# Requirement already satisfied: matplotlib!=3.6.1,>=3.4 in /usr/local/lib/python3.12/dist-packages (from seaborn) (3.10.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.12/dist-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (4.59.2)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.12/dist-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (25.0)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.12/dist-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.12/dist-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.12/dist-packages (from matplotlib!=3.6.1,>=3.4->seaborn) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas>=1.2->seaborn) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas>=1.2->seaborn) (2025.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.4->seaborn) (1.17.0)

# %%
import seaborn as sns
# 타이타닉 데이터셋 불러오기
df = sns.load_dataset('titanic')

# %%
# 전체 생존률
df['survived'].value_counts(normalize=True)
# 성별에 따른 생존률
df.groupby('sex')['survived'].mean()
# 등급(pclass)별 생존률
df.groupby('pclass')['survived'].mean()
# Out:
# pclass
# 1    0.629630
# 2    0.472826
# 3    0.242363
# Name: survived, dtype: float64

# %%
import matplotlib.pyplot as plt
# 요금(fare)과 생존 관계
# 요금 분포와 생존 여부 시각화
sns.histplot(data=df, x='fare' , hue = 'survived' , bins= 30, kde=True )
plt.title("Fare distribution by survival")
plt.show()
